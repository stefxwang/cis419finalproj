# %%
import json
import matplotlib.pyplot as plt
from sklearn.preprocessing import Normalizer
import datetime
import numpy as np

# %%
data = json.load(open('modified_Data.json'))["data"]

# %%
n = Normalizer()
dayofweek = list()
createdTime = list()
likes = list()
dayofweekCount = np.zeros(7)
dayofweekLikesCount = np.zeros(7)

# %%
for i in range(len(data)):
    dayofweek.append(data[i]['dayofweek'])
    dayofweekCount[data[i]['dayofweek']] += 1
    dayofweekLikesCount[data[i]['dayofweek']] += data[i]['likes']
    '''ordinal time is 1 per day'''
    createdTime.append(datetime.date.fromordinal(data[i]['created_time']))
    likes.append(data[i]['likes'])

# %%
plt.figure(1, figsize=(20,10))
plt.scatter(createdTime, likes, 1)

plt.figure(2, figsize=(20,10))
plt.scatter(dayofweek, likes, 1)

plt.figure(3, figsize=(20,10))
plt.hist(likes, 50)

plt.figure(4, figsize=(20,10))
plt.bar(np.arange(7), dayofweekCount)

plt.figure(5, figsize=(20,10))
plt.bar(np.arange(7), dayofweekLikesCount)

plt.figure(6, figsize=(20,10))
plt.hist(createdTime, 80, [datetime.date(2016, 1, 1), datetime.date(2017, 11, 22)])
# Out:
# (array([   0.,    0.,    0.,    0.,    0.,    8.,    4.,    3.,    2.,
#            0.,    6.,    0.,    2.,    0.,    2.,    0.,    0.,    0.,
#            0.,    1.,    0.,    1.,    0.,    1.,    0.,    1.,    0.,
#            0.,    1.,    1.,    0.,    4.,    1.,   13.,   10.,    3.,
#            4.,   10.,    6.,   11.,    6.,    3.,    3.,    3.,    0.,
#            1.,    6.,    8.,    9.,   34.,   76.,  255.,  397.,  544.,
#          385.,  225.,  308.,  119.,   47.,   48.,   27.,   27.,   19.,
#           14.,   29.,   20.,   28.,   19.,   16.,   30.,   32.,   32.,
#           63.,   69.,   37.,   67.,   79.,   58.,   54.,   79.]),
#  array([ 735964.    ,  735972.6375,  735981.275 ,  735989.9125,
#          735998.55  ,  736007.1875,  736015.825 ,  736024.4625,
#          736033.1   ,  736041.7375,  736050.375 ,  736059.0125,
#          736067.65  ,  736076.2875,  736084.925 ,  736093.5625,
#          736102.2   ,  736110.8375,  736119.475 ,  736128.1125,
#          736136.75  ,  736145.3875,  736154.025 ,  736162.6625,
#          736171.3   ,  736179.9375,  736188.575 ,  736197.2125,
#          736205.85  ,  736214.4875,  736223.125 ,  736231.7625,
#          736240.4   ,  736249.0375,  736257.675 ,  736266.3125,
#          736274.95  ,  736283.5875,  736292.225 ,  736300.8625,
#          736309.5   ,  736318.1375,  736326.775 ,  736335.4125,
#          736344.05  ,  736352.6875,  736361.325 ,  736369.9625,
#          736378.6   ,  736387.2375,  736395.875 ,  736404.5125,
#          736413.15  ,  736421.7875,  736430.425 ,  736439.0625,
#          736447.7   ,  736456.3375,  736464.975 ,  736473.6125,
#          736482.25  ,  736490.8875,  736499.525 ,  736508.1625,
#          736516.8   ,  736525.4375,  736534.075 ,  736542.7125,
#          736551.35  ,  736559.9875,  736568.625 ,  736577.2625,
#          736585.9   ,  736594.5375,  736603.175 ,  736611.8125,
#          736620.45  ,  736629.0875,  736637.725 ,  736646.3625,  736655.    ]),
#  <a list of 80 Patch objects>)

# %%
plt.show()
